# %% [markdown]
# # This notebook is used to generate all figures in the paper "Tight bounds on the mutual coherence of sensing matrices for Wigner D-functions on regular grid"

# %% [markdown]
# To generate Figure 1 run `Figure_1.py`

# %%
exec(open("./Figure_1.py").read())

# %% [markdown]
# To generate Figure 2, run `Figure_2_2D.py`. In this code we run with smaller size.

# %%
exec(open("./Figure_2_2D.py").read())

# %% [markdown]
# If you want to generate the same figure, just change the variables as follows `Blist = np.arange(4,48,2)`,
# `N = 300`,
# `m = np.arange(7,N,2).astype(np.int64)`. Since it computes all combinations, it takes sometimes to finish. We also provide the save version as follows

# %%
 exec(open("./Figure_2_2D_savefile.py").read())

# %% [markdown]
# For one dimensional case, we can generate it by using `Figure_2_1D.py`

# %%
 exec(open("./Figure_2_1D.py").read())

# %% [markdown]
# To generate Figure 3, run `Figure_3.py`

# %%
 exec(open("./Figure_3.py").read())
# Out:
# GrDe     -- Samples 17, Coherence  0.5018551091365046,  Welch Bound 0.21790836115787035, and Legendre Bound 0.24138419353977386
# ADAM     -- Samples 17, Coherence  0.48527258842742843,  Welch Bound 0.21790836115787035, and Legendre Bound 0.24138419353977386
# AdaDelta -- Samples 17, Coherence  0.6249797203170283,  Welch Bound 0.21790836115787035, and Legendre Bound 0.24138419353977386
# AdaGrad  -- Samples 17, Coherence  0.488437444468883,  Welch Bound 0.21790836115787035, and Legendre Bound 0.24138419353977386
# GrDe     -- Samples 25, Coherence  0.38647325174492975,  Welch Bound 0.16862305577755088, and Legendre Bound 0.17035513299239113
# ADAM     -- Samples 25, Coherence  0.3534948800321969,  Welch Bound 0.16862305577755088, and Legendre Bound 0.17035513299239113
# AdaDelta -- Samples 25, Coherence  0.42291359959481145,  Welch Bound 0.16862305577755088, and Legendre Bound 0.17035513299239113
# ...

# %% [markdown]
# To generate Figure 4, run `Figure_4.py`

# %%
 exec(open("./Figure_4.py").read())
# Out:
# GrDe     -- Samples 17, Coherence  0.6786885851481025,  Welch Bound 0.22207362827566876, and Legendre Bound 0.6786885851481026
# ADAM     -- Samples 17, Coherence  0.6786885851481025,  Welch Bound 0.22207362827566876, and Legendre Bound 0.6786885851481026
# AdaDelta -- Samples 17, Coherence  0.6786885851481025,  Welch Bound 0.22207362827566876, and Legendre Bound 0.6786885851481026
# AdaGrad  -- Samples 17, Coherence  0.6786885851481025,  Welch Bound 0.22207362827566876, and Legendre Bound 0.6786885851481026
# GrDe     -- Samples 25, Coherence  0.5625394832790667,  Welch Bound 0.17407765595569785, and Legendre Bound 0.5625394832790668
# ADAM     -- Samples 25, Coherence  0.5625394832790667,  Welch Bound 0.17407765595569785, and Legendre Bound 0.5625394832790668
# AdaDelta -- Samples 25, Coherence  0.5625394832790667,  Welch Bound 0.17407765595569785, and Legendre Bound 0.5625394832790668
# ...
